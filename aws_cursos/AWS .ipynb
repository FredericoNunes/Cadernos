# %% [markdown]
# # Manipular Instancias Aws
#
# * Cosole Web
# * CLI
# * SDK python (boto). sei nada disso

# %% [markdown]
# # Core Services
# * EC2
#     * Pay as you go
# * EBS
#     * Disk space for instance
# * S3
#     * Storing an retrive data
#     * Varios objetos ate snapshot de data base
# * Infra
# * VPC
#     * Virtual Private Clound (VPC) use same concepts as on premise networking
#     * Montar a rede cloud de uma empresa
#
# * Security Group
#     * act as built in firewall / method that control trafic

# %% [markdown]
# # Serviços Integrados
#
#    * Aplication Loand Balance
#        * Load balance é uma configuração utilizada para redistribuir as requisições entre dois ou mais webservers
#        * Listeners, Target e Target Group
#    * Auto Scaling
#        * Add and remove EC2 Capacity
#        * Scaling Out Lauch Instance
#        * Scaling In Terminate Instance
#        * Autoscaling
#            * Lauch Configuration = What to deploy
#            * Auto Scaling Group = Where
#            * Auto Scaling Policy = When
#
#    * Amazon Route 53
#        * DNS Domain Name System (Alterar de Ip para Humano Friendly)
#    * Amazon RDS
#        * Managed service that sets up and operates a relational database in the cloud
#    * AWS Lambda
#        * Serveless Compute
#        * No Servers to Manage
#        * Event Driven Compute
#        * (Example Image Reconigion)
#        * Use Case
#           * Automated Back Up
#           * Procec
#           * IoT
#           * Event Driven Log Analisys, Transformations
#           * Operate Serveless WebSites
#           * Re-Size Image/ RealTime Straming Data
#    * AWS Elastic Beanstalk
#        * Platform as a Service
#        * Quick Deployment of your applications
#        * Inside
#            * Your code
#            * Aplications service
#            * Http service
#            * Operating System
#            * Language interpreter
#            * Host
#    * Amazon Simple Notification Service
#        * Micro service comunications
#        * pub/messaging and mobile communication
#        * can be used to start a lambda service
#    * Amazon CloundWatch
#        * Monitor Aws resources
#            * System Utilization
#            * Monitor Log Files
#            * Set Alarms
#        * Set Actions
#    * Amazon CloundFront
#        * Content Delivery Network
#        * Edge Location / Regional Edge Caches
#        * Web / RTMP
#    * Amazon Clound Formation
#        * automate repeted resorces
#        * manipulate instances replications draging mouse like draw.io
#        * inside properties you write options in the instance (VPC)
#        * Read Template File and create a Stack

# %% [markdown]
# # Achitecture
#    * Security
#        * Indentity and access management
#        * Detective Controls
#        * Infrastructure protection
#        * Data Protection
#        * Incidente Response
#        * Design Principles
#            * Security at all layers
#            * Enable traceability
#            * Apply principle of least privilege
#            * securiting your system
#            * Automate
#    * Reliability
#        * Recover
#    * Performance effciencey
#        * Select customizable solutions
#        * Review to innovate
#        * Monitor
#        * Trade-offs
#    * Cost optimization
#    * Operational excellence

# %% [markdown]
# # Security
# * IAM
#     * user = permanent name operator (authentication method) = Permanet
#     * groups = colections of groups
#     * Role = is not permition = (authentication method) = temp
#
#     * Policy Docs (autorization)(list the api allowed) link withs all three before
#        * explict deny override all before allowed
#
# * Inspector
#     * Check security problens and enforce good practice
#     * Helps Define our security policy
#
# * Shield
#     Managed Distributed Denial Service (DDoS)

# %% [markdown]
# # Pricing and Support
#
# * Pay For:
#     * Compute Capacity
#     * Storeage
#     * Outbound data Transfer (aggregated)
#
# * No charge for
#     * inound data transfer
#
#
# * EC2 Clock work
#
#
# # Trust Advisor
#
# * Painel para otimimzar custo
#
# #  Support
# * Proactive guidance
#     * technical Account managet (TAM)
# * Best Practices
#     * Trusted Advisor
# * Account Assistence
#     * Aws Support Concierge (Billing Suppot)
#
# * Plans
#     * Basic Support
#     * Developer Support
#     * Business Support
#     * Enterprise Support
